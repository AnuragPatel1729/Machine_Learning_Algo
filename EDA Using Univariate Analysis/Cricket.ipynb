# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Batting/ODI data.csv' , index_col=0)

# %%
df.head()
# Out:
#                         Player       Span  Mat Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144  33.37
#
#       BF     SR 100  50   0  Unnamed: 13
# 0  21367  86.23  49  96  20          NaN
# 1  18048  78.86  25  93  15          NaN
# 2  17046  80.39  30  82  20          NaN
# 3  14725   91.2  28  68  34          NaN
# 4  16020  78.96  19  77  28          NaN

# %%
df.tail()
# Out:
#                   Player       Span  Mat Inns NO Runs HS Ave BF SR 100 50  0  \
# 45       ZS Ansari (ENG)  2015-2015    1    -  -    -  -   -  -  -   -  -  -
# 46  Ariful Haque (BDESH)  2018-2018    1    -  -    -  -   -  -  -   -  -  -
# 47    Ashfaq Ahmed (PAK)  1994-1994    3    -  -    -  -   -  -  -   -  -  -
# 48        MD Bailey (NZ)  1998-1998    1    -  -    -  -   -  -  -   -  -  -
# 49        GR Beard (AUS)  1981-1981    2    -  -    -  -   -  -  -   -  -  -
#
#     Unnamed: 13
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN

# %%
df.replace('-',value= np.nan)
# Out:
#                          Player       Span  Mat Inns   NO   Runs    HS    Ave  \
# 0          SR Tendulkar (INDIA)  1989-2012  463  452   41  18426  200*  44.83
# 1   KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380   41  14234   169  41.98
# 2          RT Ponting (AUS/ICC)  1995-2012  375  365   39  13704   164  42.03
# 3       ST Jayasuriya (Asia/SL)  1989-2011  445  433   18  13430   189  32.36
# 4    DPMD Jayawardene (Asia/SL)  1998-2015  448  418   39  12650   144  33.37
# ..                          ...        ...  ...  ...  ...    ...   ...    ...
# 45              ZS Ansari (ENG)  2015-2015    1  NaN  NaN    NaN   NaN    NaN
# 46         Ariful Haque (BDESH)  2018-2018    1  NaN  NaN    NaN   NaN    NaN
# 47           Ashfaq Ahmed (PAK)  1994-1994    3  NaN  NaN    NaN   NaN    NaN
# 48               MD Bailey (NZ)  1998-1998    1  NaN  NaN    NaN   NaN    NaN
# 49               GR Beard (AUS)  1981-1981    2  NaN  NaN    NaN   NaN    NaN
#
# ...

# %%
df.drop(df.columns[:-1],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.tail()
# Out:
#    Player  Span  Mat Inns NO Runs HS Ave BF SR 100 50  0  Unnamed: 13
# 45   None  None  NaN    -  -    -  -   -  -  -   -  -  -          NaN
# 46   None  None  NaN    -  -    -  -   -  -  -   -  -  -          NaN
# 47   None  None  NaN    -  -    -  -   -  -  -   -  -  -          NaN
# 48   None  None  NaN    -  -    -  -   -  -  -   -  -  -          NaN
# 49   None  None  NaN    -  -    -  -   -  -  -   -  -  -          NaN

# %%
df[df['Inns'].isna()]
# Out:
#    Player  Span  Mat  Inns    NO  Runs    HS   Ave    BF    SR   100    50  \
# 0    None  None  NaN  None  None  None  None  None  None  None  None  None
# 1    None  None  NaN  None  None  None  None  None  None  None  None  None
# 2    None  None  NaN  None  None  None  None  None  None  None  None  None
# 3    None  None  NaN  None  None  None  None  None  None  None  None  None
# 4    None  None  NaN  None  None  None  None  None  None  None  None  None
# ..    ...   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 35   None  None  NaN  None  None  None  None  None  None  None  None  None
# 36   None  None  NaN  None  None  None  None     -  None     -  None  None
# 37   None  None  NaN  None  None  None  None  None  None  None  None  None
# 38   None  None  NaN  None  None  None  None  None  None  None  None  None
# 39   None  None  NaN  None  None  None  None  None  None  None  None  None
#
#        0  Unnamed: 13
# 0   None          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player       0 non-null      object
#  1   Span         0 non-null      object
#  2   Mat          0 non-null      float64
#  3   Inns         10 non-null     object
#  4   NO           10 non-null     object
#  5   Runs         10 non-null     object
#  6   HS           10 non-null     object
#  7   Ave          130 non-null    object
#  8   BF           10 non-null     object
#  9   SR           19 non-null     object
#  10  100          10 non-null     object
#  11  50           10 non-null     object
#  12  0            10 non-null     object
#  13  Unnamed: 13  0 non-null      float64
# dtypes: float64(2), object(12)
# memory usage: 293.0+ KB

# %%
df.shape
# Out:
# (0, 15)

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [Player, Span, Mat, Inns, NO, Runs, HS, Ave, BF, SR, 100, 50, 0, Unnamed: 13, Years Played]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player       2500 non-null   object
#  1   Span         2500 non-null   object
#  2   Mat          2500 non-null   int64
#  3   Inns         2500 non-null   object
#  4   NO           2500 non-null   object
#  5   Runs         2500 non-null   object
#  6   HS           2500 non-null   object
#  7   Ave          2500 non-null   object
#  8   BF           2500 non-null   object
#  9   SR           2500 non-null   object
#  10  100          2500 non-null   object
#  11  50           2500 non-null   object
#  12  0            2500 non-null   object
#  13  Unnamed: 13  0 non-null      float64
# dtypes: float64(1), int64(1), object(12)
# memory usage: 293.0+ KB

# %%
df.isnull().sum()
# Out:
# Player            0
# Span              0
# Mat               0
# Inns              0
# NO                0
# Runs              0
# HS                0
# Ave               0
# BF                0
# SR                0
# 100               0
# 50                0
# 0                 0
# Unnamed: 13    2500
# dtype: int64

# %%
df.describe()
# Out:
#                Mat  Unnamed: 13
# count  2500.000000          0.0
# mean     37.161600          NaN
# std      58.885075          NaN
# min       1.000000          NaN
# 25%       4.000000          NaN
# 50%      13.000000          NaN
# 75%      43.000000          NaN
# max     463.000000          NaN

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Span']
# Out:
# 0     1989-2012
# 1     2000-2015
# 2     1995-2012
# 3     1989-2011
# 4     1998-2015
#         ...
# 45    2015-2015
# 46    2018-2018
# 47    1994-1994
# 48    1998-1998
# 49    1981-1981
# Name: Span, Length: 2500, dtype: object

# %%
def calculate_age(span):
    a,b = span.split('-')
    age = int(b)-int(a)+1
    return age
df['Years Played'] =df['Span'].apply(calculate_age)
df.head()
# Out:
#                         Player       Span  Mat Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144  33.37
#
#       BF     SR 100  50   0  Unnamed: 13  Years Played
# 0  21367  86.23  49  96  20          NaN            24
# 1  18048  78.86  25  93  15          NaN            16
# 2  17046  80.39  30  82  20          NaN            18
# 3  14725   91.2  28  68  34          NaN            23
# 4  16020  78.96  19  77  28          NaN            18

# %%
sns.countplot(df['Years Played'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Years Played', ylabel='count'>

# %%
df.astype({'Inns':'int64'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-d4327fbd5f2a> in <module>
# ----> 1 df.astype({'Inns':'int64'})
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    6224                     res_col = col.copy() if copy else col
#    6225                 else:
# -> 6226                     res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6227                 results.append(res_col)
#    6228
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# ...
